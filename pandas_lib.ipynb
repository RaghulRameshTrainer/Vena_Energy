# %%
import pandas as pd

pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',10)
pd.set_option('display.width',1000)

# %%
df=pd.read_csv(r'C:\Users\RaghulRamesh\Downloads\18 - Day - 18 - Linear Regression Practise Python\18 - Day - 18 - Linear Regression Practise Python\company.csv')

# %%
df
# Out:
#                        Company   Age  Salary       Place
# 0                          TCS  20.0     NaN     Chennai
# 1                      Infosys  30.0     NaN      Mumbai
# 2                          TCS  35.0  2300.0    Calcutta
# 3                      Infosys  40.0  3000.0       Delhi
# 4                          TCS  23.0  4000.0      Mumbai
# 5                      Infosys   NaN  5000.0    Calcutta
# 6                          TCS   NaN  6000.0     Chennai
# 7                      Infosys  23.0  7000.0      Mumbai
# 8                          TCS  34.0  8000.0    Calcutta
# 9                          CTS  45.0  9000.0       Delhi
# 10                         CTS  23.0     NaN      Mumbai
# 11                         CTS  34.0  1089.0    Calcutta
# 12                         CTS  45.0     NaN     Chennai
# 13                         CTS  18.0  1234.0      Mumbai
# 14                     Infosys  40.0  3000.0    Calcutta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#               Age       Salary
# count  130.000000   124.000000
# mean    30.484615  5312.467742
# std     11.096640  2573.764683
# min      0.000000  1089.000000
# 25%     22.000000  3030.000000
# 50%     32.500000  5000.000000
# 75%     37.750000  8000.000000
# max     54.000000  9876.000000

# %%
df.head()
# Out:
#    Company   Age  Salary     Place
# 0      TCS  20.0     NaN   Chennai
# 1  Infosys  30.0     NaN    Mumbai
# 2      TCS  35.0  2300.0  Calcutta
# 3  Infosys  40.0  3000.0     Delhi
# 4      TCS  23.0  4000.0    Mumbai

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place
# 143      TCS  33.0  9024.0  Calcutta
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin

# %%
df.head(15)
# Out:
#     Company   Age  Salary     Place
# 0       TCS  20.0     NaN   Chennai
# 1   Infosys  30.0     NaN    Mumbai
# 2       TCS  35.0  2300.0  Calcutta
# 3   Infosys  40.0  3000.0     Delhi
# 4       TCS  23.0  4000.0    Mumbai
# 5   Infosys   NaN  5000.0  Calcutta
# 6       TCS   NaN  6000.0   Chennai
# 7   Infosys  23.0  7000.0    Mumbai
# 8       TCS  34.0  8000.0  Calcutta
# 9       CTS  45.0  9000.0     Delhi
# 10      CTS  23.0     NaN    Mumbai
# 11      CTS  34.0  1089.0  Calcutta
# 12      CTS  45.0     NaN   Chennai
# 13      CTS  18.0  1234.0    Mumbai
# 14  Infosys  40.0  3000.0  Calcutta

# %%
df.tail(10)
# Out:
#              Company   Age  Salary      Place
# 138              CTS  44.0  3033.0     Cochin
# 139       Congnizant  22.0  2934.0      Noida
# 140          Infosys  44.0  4034.0  Hyderabad
# 141              TCS  33.0  5034.0   Calcutta
# 142  Infosys Pvt Lmt  22.0  8202.0     Mumbai
# 143              TCS  33.0  9024.0   Calcutta
# 144          Infosys  22.0  8787.0   Calcutta
# 145          Infosys  44.0  4034.0      Delhi
# 146              TCS  33.0  5034.0     Mumbai
# 147          Infosys  22.0  8202.0     Cochin

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place'], dtype='object')

# %%
df['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS','Infosys Pvt Lmt':'Infosys','Congnizant':'CTS'}, inplace=True)

# %%
df['Company'].value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df['Company'].isnull().sum()
# Out:
# 8

# %%
df['Company'].mode()[0]
# Out:
# 'TCS'

# %%
df['Company'].fillna(df['Company'].mode()[0],inplace=True)

# %%
df['Company'].isnull().sum()
# Out:
# 0

# %%
df['Company'].value_counts()
# Out:
# TCS        63
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place'], dtype='object')

# %%
df['Age'].isnull().sum()
# Out:
# 18

# %%
df['Age'].mean()
# Out:
# 30.484615384615385

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age']
# Out:
# 0      20.000000
# 1      30.000000
# 2      35.000000
# 3      40.000000
# 4      23.000000
# 5      30.484615
# 6      30.484615
# 7      23.000000
# 8      34.000000
# 9      45.000000
# 10     23.000000
# 11     34.000000
# 12     45.000000
# 13     18.000000
# 14     40.000000
# 15     23.000000
# 16     23.000000
# 17     34.000000
# 18     22.000000
# 19     32.000000
# 20     37.000000
# 21     50.000000
# 22     21.000000
# 23     30.484615
# 24     30.484615
# 25     23.000000
# 26     34.000000
# 27     45.000000
# 28     23.000000
# 29     35.000000
# 30     46.000000
# 31     20.000000
# 32     45.000000
# 33     36.000000
# 34     26.000000
# 35     35.000000
# 36     32.000000
# 37     35.000000
# 38     34.000000
# 39     41.000000
# 40     24.000000
# 41     30.484615
# 42     30.484615
# 43     25.000000
# 44     35.000000
# 45     46.000000
# 46     24.000000
# 47     32.000000
# 48     43.000000
# 49     19.000000
# 50     41.000000
# 51     24.000000
# ...

# %%
df['Salary'].isnull().sum()
# Out:
# 24

# %%
df['Salary'].min()
# Out:
# 1089.0

# %%
df['Salary'].fillna(1111, inplace=True)

# %%
df['Salary'].isnull().sum()
# Out:
# 0

# %%
df['Place'].value_counts()
# Out:
# Mumbai        37
# Calcutta      33
# Chennai       14
# Delhi         14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: Place, dtype: int64

# %%
df['Place'].isnull().sum()
# Out:
# 14

# %%
df['Place'].fillna('Lucknow',inplace=True)

# %%
df['Place']
# Out:
# 0         Chennai
# 1          Mumbai
# 2        Calcutta
# 3           Delhi
# 4          Mumbai
# 5        Calcutta
# 6         Chennai
# 7          Mumbai
# 8        Calcutta
# 9           Delhi
# 10         Mumbai
# 11       Calcutta
# 12        Chennai
# 13         Mumbai
# 14       Calcutta
# 15          Delhi
# 16     Podicherry
# 17         Cochin
# 18        Chennai
# 19         Mumbai
# 20       Calcutta
# 21          Delhi
# 22         Mumbai
# 23         Cochin
# 24        Chennai
# 25         Mumbai
# 26       Calcutta
# 27          Delhi
# 28         Mumbai
# 29         Cochin
# 30        Chennai
# 31         Mumbai
# 32       Calcutta
# 33        Lucknow
# 34        Lucknow
# 35        Lucknow
# 36          Noida
# 37      Hyderabad
# 38       Calcutta
# 39         Mumbai
# 40       Calcutta
# 41        Lucknow
# 42        Lucknow
# 43        Lucknow
# 44          Noida
# 45      Hyderabad
# 46       Calcutta
# 47         Mumbai
# 48         Mumbai
# 49         Cochin
# ...

# %%
df
# Out:
#      Company        Age  Salary       Place
# 0        TCS  20.000000  1111.0     Chennai
# 1    Infosys  30.000000  1111.0      Mumbai
# 2        TCS  35.000000  2300.0    Calcutta
# 3    Infosys  40.000000  3000.0       Delhi
# 4        TCS  23.000000  4000.0      Mumbai
# 5    Infosys  30.484615  5000.0    Calcutta
# 6        TCS  30.484615  6000.0     Chennai
# 7    Infosys  23.000000  7000.0      Mumbai
# 8        TCS  34.000000  8000.0    Calcutta
# 9        CTS  45.000000  9000.0       Delhi
# 10       CTS  23.000000  1111.0      Mumbai
# 11       CTS  34.000000  1089.0    Calcutta
# 12       CTS  45.000000  1111.0     Chennai
# 13       CTS  18.000000  1234.0      Mumbai
# 14   Infosys  40.000000  3000.0    Calcutta
# 15       TCS  23.000000  3000.0       Delhi
# 16   Infosys  23.000000  3030.0  Podicherry
# 17       TCS  34.000000  5000.0      Cochin
# 18       TCS  22.000000  1111.0     Chennai
# 19   Infosys  32.000000  1111.0      Mumbai
# ...

# %%
df
# Out:
#      Company        Age  Salary       Place
# 0        TCS  20.000000  1111.0     Chennai
# 1    Infosys  30.000000  1111.0      Mumbai
# 2        TCS  35.000000  2300.0    Calcutta
# 3    Infosys  40.000000  3000.0       Delhi
# 4        TCS  23.000000  4000.0      Mumbai
# 5    Infosys  30.484615  5000.0    Calcutta
# 6        TCS  30.484615  6000.0     Chennai
# 7    Infosys  23.000000  7000.0      Mumbai
# 8        TCS  34.000000  8000.0    Calcutta
# 9        CTS  45.000000  9000.0       Delhi
# 10       CTS  23.000000  1111.0      Mumbai
# 11       CTS  34.000000  1089.0    Calcutta
# 12       CTS  45.000000  1111.0     Chennai
# 13       CTS  18.000000  1234.0      Mumbai
# 14   Infosys  40.000000  3000.0    Calcutta
# 15       TCS  23.000000  3000.0       Delhi
# 16   Infosys  23.000000  3030.0  Podicherry
# 17       TCS  34.000000  5000.0      Cochin
# 18       TCS  22.000000  1111.0     Chennai
# 19   Infosys  32.000000  1111.0      Mumbai
# ...

# %%
df.iloc[0:10,0:3]
# Out:
#    Company        Age  Salary
# 0      TCS  20.000000  1111.0
# 1  Infosys  30.000000  1111.0
# 2      TCS  35.000000  2300.0
# 3  Infosys  40.000000  3000.0
# 4      TCS  23.000000  4000.0
# 5  Infosys  30.484615  5000.0
# 6      TCS  30.484615  6000.0
# 7  Infosys  23.000000  7000.0
# 8      TCS  34.000000  8000.0
# 9      CTS  45.000000  9000.0

# %%
df.iloc[100:110,:]
# Out:
#      Company   Age  Salary       Place
# 100      CTS  22.0  1111.0      Cochin
# 101      CTS   0.0  2034.0  Podicherry
# 102      CTS  44.0  1111.0      Mumbai
# 103      CTS  22.0  2934.0    Calcutta
# 104  Infosys  44.0  4034.0       Delhi
# 105      TCS  33.0  5034.0      Mumbai
# 106  Infosys  22.0  8202.0      Cochin
# 107      TCS   0.0  9024.0     Chennai
# 108      TCS  33.0  1111.0      Mumbai
# 109      TCS  33.0  1111.0    Calcutta

# %%
df.loc[0:10,['Place','Company','Salary']]
# Out:
#        Place  Company  Salary
# 0    Chennai      TCS  1111.0
# 1     Mumbai  Infosys  1111.0
# 2   Calcutta      TCS  2300.0
# 3      Delhi  Infosys  3000.0
# 4     Mumbai      TCS  4000.0
# 5   Calcutta  Infosys  5000.0
# 6    Chennai      TCS  6000.0
# 7     Mumbai  Infosys  7000.0
# 8   Calcutta      TCS  8000.0
# 9      Delhi      CTS  9000.0
# 10    Mumbai      CTS  1111.0

# %% [markdown]
# # null data handlings

# %%
df.dropna()
# Out:
#      Company        Age  Salary       Place
# 0        TCS  20.000000  1111.0     Chennai
# 1    Infosys  30.000000  1111.0      Mumbai
# 2        TCS  35.000000  2300.0    Calcutta
# 3    Infosys  40.000000  3000.0       Delhi
# 4        TCS  23.000000  4000.0      Mumbai
# 5    Infosys  30.484615  5000.0    Calcutta
# 6        TCS  30.484615  6000.0     Chennai
# 7    Infosys  23.000000  7000.0      Mumbai
# 8        TCS  34.000000  8000.0    Calcutta
# 9        CTS  45.000000  9000.0       Delhi
# 10       CTS  23.000000  1111.0      Mumbai
# 11       CTS  34.000000  1089.0    Calcutta
# 12       CTS  45.000000  1111.0     Chennai
# 13       CTS  18.000000  1234.0      Mumbai
# 14   Infosys  40.000000  3000.0    Calcutta
# 15       TCS  23.000000  3000.0       Delhi
# 16   Infosys  23.000000  3030.0  Podicherry
# 17       TCS  34.000000  5000.0      Cochin
# 18       TCS  22.000000  1111.0     Chennai
# 19   Infosys  32.000000  1111.0      Mumbai
# ...

# %%
df.dropna()
# Out:
#      Company        Age  Salary       Place
# 0        TCS  20.000000  1111.0     Chennai
# 1    Infosys  30.000000  1111.0      Mumbai
# 2        TCS  35.000000  2300.0    Calcutta
# 3    Infosys  40.000000  3000.0       Delhi
# 4        TCS  23.000000  4000.0      Mumbai
# 5    Infosys  30.484615  5000.0    Calcutta
# 6        TCS  30.484615  6000.0     Chennai
# 7    Infosys  23.000000  7000.0      Mumbai
# 8        TCS  34.000000  8000.0    Calcutta
# 9        CTS  45.000000  9000.0       Delhi
# 10       CTS  23.000000  1111.0      Mumbai
# 11       CTS  34.000000  1089.0    Calcutta
# 12       CTS  45.000000  1111.0     Chennai
# 13       CTS  18.000000  1234.0      Mumbai
# 14   Infosys  40.000000  3000.0    Calcutta
# 15       TCS  23.000000  3000.0       Delhi
# 16   Infosys  23.000000  3030.0  Podicherry
# 17       TCS  34.000000  5000.0      Cochin
# 18       TCS  22.000000  1111.0     Chennai
# 19   Infosys  32.000000  1111.0      Mumbai
# ...

# %%
df.isnull().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# Place      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Company    148
# Age        148
# Salary     148
# Place      148
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140 entries, 0 to 143
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      140 non-null    float64
#  2   Salary   140 non-null    float64
#  3   Place    140 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 5.5+ KB

# %%
df.drop(columns=['Place'], inplace=True)
# Out:
# C:\Users\RaghulRamesh\AppData\Local\Temp\ipykernel_10688\3694948898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Place'], inplace=True)

# %%
df['Category']='Highly Paid'
# Out:
# C:\Users\RaghulRamesh\AppData\Local\Temp\ipykernel_10688\1956298074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']='Highly Paid'

# %%
df
# Out:
#      Company        Age  Salary     Category
# 0        TCS  20.000000  1111.0  Highly Paid
# 1    Infosys  30.000000  1111.0  Highly Paid
# 2        TCS  35.000000  2300.0  Highly Paid
# 3    Infosys  40.000000  3000.0  Highly Paid
# 4        TCS  23.000000  4000.0  Highly Paid
# 5    Infosys  30.484615  5000.0  Highly Paid
# 6        TCS  30.484615  6000.0  Highly Paid
# 7    Infosys  23.000000  7000.0  Highly Paid
# 8        TCS  34.000000  8000.0  Highly Paid
# 9        CTS  45.000000  9000.0  Highly Paid
# 10       CTS  23.000000  1111.0  Highly Paid
# 11       CTS  34.000000  1089.0  Highly Paid
# 12       CTS  45.000000  1111.0  Highly Paid
# 13       CTS  18.000000  1234.0  Highly Paid
# 14   Infosys  40.000000  3000.0  Highly Paid
# 15       TCS  23.000000  3000.0  Highly Paid
# 16   Infosys  23.000000  3030.0  Highly Paid
# 17       TCS  34.000000  5000.0  Highly Paid
# 18       TCS  22.000000  1111.0  Highly Paid
# 19   Infosys  32.000000  1111.0  Highly Paid
# ...

# %%
def get_category(sal):
    if sal>=5000:
        return "Highly Paid"
    else:
        return "Less paid"

# %%
df['Category']=df['Salary'].apply(get_category)
# Out:
# C:\Users\RaghulRamesh\AppData\Local\Temp\ipykernel_10688\3332031433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']=df['Salary'].apply(get_category)

# %%
df
# Out:
#      Company        Age  Salary     Category
# 0        TCS  20.000000  1111.0    Less paid
# 1    Infosys  30.000000  1111.0    Less paid
# 2        TCS  35.000000  2300.0    Less paid
# 3    Infosys  40.000000  3000.0    Less paid
# 4        TCS  23.000000  4000.0    Less paid
# 5    Infosys  30.484615  5000.0  Highly Paid
# 6        TCS  30.484615  6000.0  Highly Paid
# 7    Infosys  23.000000  7000.0  Highly Paid
# 8        TCS  34.000000  8000.0  Highly Paid
# 9        CTS  45.000000  9000.0  Highly Paid
# 10       CTS  23.000000  1111.0    Less paid
# 11       CTS  34.000000  1089.0    Less paid
# 12       CTS  45.000000  1111.0    Less paid
# 13       CTS  18.000000  1234.0    Less paid
# 14   Infosys  40.000000  3000.0    Less paid
# 15       TCS  23.000000  3000.0    Less paid
# 16   Infosys  23.000000  3030.0    Less paid
# 17       TCS  34.000000  5000.0  Highly Paid
# 18       TCS  22.000000  1111.0    Less paid
# 19   Infosys  32.000000  1111.0    Less paid
# ...

# %%
df[(df['Company']=='Infosys') & (df['Age']<30)]
# Out:
#      Company   Age  Salary     Category
# 7    Infosys  23.0  7000.0  Highly Paid
# 16   Infosys  23.0  3030.0    Less paid
# 25   Infosys  23.0  8943.0  Highly Paid
# 34   Infosys  26.0  8202.0  Highly Paid
# 43   Infosys  25.0  7000.0  Highly Paid
# 52   Infosys  21.0  3030.0    Less paid
# 70   Infosys  21.0  8202.0  Highly Paid
# 79   Infosys  26.0  7000.0  Highly Paid
# 88   Infosys   0.0  3030.0    Less paid
# 97   Infosys  22.0  8943.0  Highly Paid
# 106  Infosys  22.0  8202.0  Highly Paid
# 111  Infosys   0.0  3234.0    Less paid
# 115  Infosys  22.0  8787.0  Highly Paid
# 142  Infosys  22.0  8202.0  Highly Paid

# %%
df[df['Category']=='Highly Paid']
# Out:
#      Company        Age  Salary     Category
# 5    Infosys  30.484615  5000.0  Highly Paid
# 6        TCS  30.484615  6000.0  Highly Paid
# 7    Infosys  23.000000  7000.0  Highly Paid
# 8        TCS  34.000000  8000.0  Highly Paid
# 9        CTS  45.000000  9000.0  Highly Paid
# 17       TCS  34.000000  5000.0  Highly Paid
# 23   Infosys  30.484615  5835.0  Highly Paid
# 24       TCS  30.484615  7084.0  Highly Paid
# 25   Infosys  23.000000  8943.0  Highly Paid
# 26       TCS  34.000000  8345.0  Highly Paid
# 27       CTS  45.000000  9284.0  Highly Paid
# 28       CTS  23.000000  9876.0  Highly Paid
# 30       CTS  46.000000  7654.0  Highly Paid
# 33       TCS  36.000000  5034.0  Highly Paid
# 34   Infosys  26.000000  8202.0  Highly Paid
# 35       TCS  35.000000  9024.0  Highly Paid
# 41   Infosys  30.484615  5000.0  Highly Paid
# 42       TCS  30.484615  6000.0  Highly Paid
# 43   Infosys  25.000000  7000.0  Highly Paid
# 44       TCS  35.000000  8000.0  Highly Paid
# ...

# %%
df.rename(columns={'Salary':'Package'}, inplace=True)
# Out:
# C:\Users\RaghulRamesh\AppData\Local\Temp\ipykernel_10688\2071221637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Salary':'Package'}, inplace=True)

# %%
df
# Out:
#      Company        Age  Package     Category
# 0        TCS  20.000000   1111.0    Less paid
# 1    Infosys  30.000000   1111.0    Less paid
# 2        TCS  35.000000   2300.0    Less paid
# 3    Infosys  40.000000   3000.0    Less paid
# 4        TCS  23.000000   4000.0    Less paid
# 5    Infosys  30.484615   5000.0  Highly Paid
# 6        TCS  30.484615   6000.0  Highly Paid
# 7    Infosys  23.000000   7000.0  Highly Paid
# 8        TCS  34.000000   8000.0  Highly Paid
# 9        CTS  45.000000   9000.0  Highly Paid
# 10       CTS  23.000000   1111.0    Less paid
# 11       CTS  34.000000   1089.0    Less paid
# 12       CTS  45.000000   1111.0    Less paid
# 13       CTS  18.000000   1234.0    Less paid
# 14   Infosys  40.000000   3000.0    Less paid
# 15       TCS  23.000000   3000.0    Less paid
# 16   Infosys  23.000000   3030.0    Less paid
# 17       TCS  34.000000   5000.0  Highly Paid
# 18       TCS  22.000000   1111.0    Less paid
# ...

# %%
df.sort_values(by=['Package','Age'])
# Out:
#      Company        Age  Package     Category
# 47       CTS  32.000000   1089.0    Less paid
# 83       CTS  33.000000   1089.0    Less paid
# 119      CTS  33.000000   1089.0    Less paid
# 11       CTS  34.000000   1089.0    Less paid
# 0        TCS  20.000000   1111.0    Less paid
# 90       TCS  21.000000   1111.0    Less paid
# 18       TCS  22.000000   1111.0    Less paid
# 82       CTS  22.000000   1111.0    Less paid
# 100      CTS  22.000000   1111.0    Less paid
# 118      CTS  22.000000   1111.0    Less paid
# 10       CTS  23.000000   1111.0    Less paid
# 46       CTS  24.000000   1111.0    Less paid
# 72       TCS  24.000000   1111.0    Less paid
# 1    Infosys  30.000000   1111.0    Less paid
# 136      TCS  30.484615   1111.0    Less paid
# 19   Infosys  32.000000   1111.0    Less paid
# 36       TCS  32.000000   1111.0    Less paid
# 108      TCS  33.000000   1111.0    Less paid
# 109      TCS  33.000000   1111.0    Less paid
# ...

# %%
df.sort_values(by=['Package','Age'],ascending=False)
# Out:
#      Company        Age  Package     Category
# 117      CTS  44.000000   9876.0  Highly Paid
# 28       CTS  23.000000   9876.0  Highly Paid
# 27       CTS  45.000000   9284.0  Highly Paid
# 99       CTS  44.000000   9284.0  Highly Paid
# 63       CTS  41.000000   9284.0  Highly Paid
# 135      CTS  40.000000   9284.0  Highly Paid
# 35       TCS  35.000000   9024.0  Highly Paid
# 71       TCS  34.000000   9024.0  Highly Paid
# 143      TCS  33.000000   9024.0  Highly Paid
# 107      TCS   0.000000   9024.0  Highly Paid
# 45       CTS  46.000000   9000.0  Highly Paid
# 9        CTS  45.000000   9000.0  Highly Paid
# 81       CTS  43.000000   9000.0  Highly Paid
# 61       TCS  25.000000   8943.0  Highly Paid
# 25   Infosys  23.000000   8943.0  Highly Paid
# 97   Infosys  22.000000   8943.0  Highly Paid
# 133      TCS  22.000000   8943.0  Highly Paid
# 116      TCS  33.000000   8787.0  Highly Paid
# 115  Infosys  22.000000   8787.0  Highly Paid
# ...

# %%
df.groupby('Company')['Package'].min()
# Out:
# Company
# CTS        1089.0
# Infosys    1111.0
# TCS        1111.0
# Name: Package, dtype: float64

# %%
df.groupby('Company')['Package'].max()
# Out:
# Company
# CTS        9876.0
# Infosys    8943.0
# TCS        9024.0
# Name: Package, dtype: float64

# %%
df.groupby(['Company','Category'])['Package'].min()
# Out:
# Company  Category
# CTS      Highly Paid    7654.0
#          Less paid      1089.0
# Infosys  Highly Paid    5000.0
#          Less paid      1111.0
# TCS      Highly Paid    5000.0
#          Less paid      1111.0
# Name: Package, dtype: float64

# %%
df.groupby(['Company','Category'])['Package'].max()
# Out:
# Company  Category
# CTS      Highly Paid    9876.0
#          Less paid      3033.0
# Infosys  Highly Paid    8943.0
#          Less paid      4034.0
# TCS      Highly Paid    9024.0
#          Less paid      4824.0
# Name: Package, dtype: float64

# %%
df
# Out:
#      Company        Age  Package     Category
# 0        TCS  20.000000   1111.0    Less paid
# 1    Infosys  30.000000   1111.0    Less paid
# 2        TCS  35.000000   2300.0    Less paid
# 3    Infosys  40.000000   3000.0    Less paid
# 4        TCS  23.000000   4000.0    Less paid
# 5    Infosys  30.484615   5000.0  Highly Paid
# 6        TCS  30.484615   6000.0  Highly Paid
# 7    Infosys  23.000000   7000.0  Highly Paid
# 8        TCS  34.000000   8000.0  Highly Paid
# 9        CTS  45.000000   9000.0  Highly Paid
# 10       CTS  23.000000   1111.0    Less paid
# 11       CTS  34.000000   1089.0    Less paid
# 12       CTS  45.000000   1111.0    Less paid
# 13       CTS  18.000000   1234.0    Less paid
# 14   Infosys  40.000000   3000.0    Less paid
# 15       TCS  23.000000   3000.0    Less paid
# 16   Infosys  23.000000   3030.0    Less paid
# 17       TCS  34.000000   5000.0  Highly Paid
# 18       TCS  22.000000   1111.0    Less paid
# ...

# %%
df.to_csv(r'C:\Users\RaghulRamesh\OneDrive\Desktop\ETL\company_data.csv',index=False)
